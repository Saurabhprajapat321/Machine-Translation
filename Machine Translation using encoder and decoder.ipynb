# %% [markdown]
# <h3 align="center">Machine Translation using encoder and decoder
# </h3>

# %% [markdown]
# ## What is Machine Translation?
# Machine translation (MT) refers to fully automated software that can translate source content into target languages. Humans may use MT to help them render text and speech into another language, or the MT software may operate without human intervention.
#
# This notebook is an implementation of the article : https://blog.keras.io/a-ten-minute-introduction-to-sequence-to-sequence-learning-in-keras.html

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers , activations , models , preprocessing , utils
import pandas as pd

print( tf.version )
# Out:
# <module 'tensorflow._api.v2.version' from '/usr/local/lib/python3.7/dist-packages/tensorflow/_api/v2/version/__init__.py'>

# %% [markdown]
# ## Reading the data

# %%
data_path = 'fra.txt'

# %%
input_texts = []
target_texts = []
with open(data_path, 'r', encoding='utf-8') as f:
    lines = f.read().split('\n')
for line in lines[: min(600, len(lines) - 1)]:
    input_text = line.split('\t')[0]
    target_text = line.split('\t')[1]
    input_texts.append(input_text)
    target_texts.append(target_text)

# %%
len(input_texts)
# Out:
# 600

# %%
zippedList =  list(zip(input_texts, target_texts))
lines = pd.DataFrame(zippedList, columns = ['input' , 'output'])

# %%
lines.tail()
# Out:
#          input                     output
# 595  Hurry up.              Magnez-vous !
# 596  I am Tom.               Je suis Tom.
# 597  I cursed.                 J'ai juré.
# 598  I did OK.   Je m'en suis bien sorti.
# 599  I did OK.  Je m'en suis bien sortie.

# %% [markdown]
# ## Preparing input data for the Encoder

# %%
input_lines = list()
for line in lines.input:
    input_lines.append( line ) 

tokenizer = preprocessing.text.Tokenizer()
tokenizer.fit_on_texts( input_lines ) 
tokenized_input_lines = tokenizer.texts_to_sequences( input_lines ) 

length_list = list()
for token_seq in tokenized_input_lines:
    length_list.append( len( token_seq ))
max_input_length = np.array( length_list ).max()
print( 'Input max length is {}'.format( max_input_length ))

padded_input_lines = preprocessing.sequence.pad_sequences( tokenized_input_lines , maxlen=max_input_length , padding='post' )
encoder_input_data = np.array( padded_input_lines )
print( 'Encoder input data shape -> {}'.format( encoder_input_data.shape ))

input_word_dict = tokenizer.word_index
num_input_tokens = len( input_word_dict )+1
print( 'Number of Input tokens = {}'.format( num_input_tokens))
# Out:
# Input max length is 3
# Encoder input data shape -> (600, 3)
# Number of Input tokens = 172

# %% [markdown]
# ## Preparing input data for the Decoder

# %%
output_lines = list()
for line in lines.output:
    output_lines.append( '<START> ' + line + ' <END>' )  

tokenizer = preprocessing.text.Tokenizer()
tokenizer.fit_on_texts( output_lines ) 
tokenized_output_lines = tokenizer.texts_to_sequences( output_lines ) 

length_list = list()
for token_seq in tokenized_output_lines:
    length_list.append( len( token_seq ))
max_output_length = np.array( length_list ).max()
print( 'Output max length is {}'.format( max_output_length ))

padded_output_lines = preprocessing.sequence.pad_sequences( tokenized_output_lines , maxlen=max_output_length, padding='post' )
decoder_input_data = np.array( padded_output_lines )
print( 'Decoder input data shape -> {}'.format( decoder_input_data.shape ))

output_word_dict = tokenizer.word_index
num_output_tokens = len( output_word_dict )+1
print( 'Number of Output tokens = {}'.format( num_output_tokens))
# Out:
# Output max length is 8
# Decoder input data shape -> (600, 8)
# Number of Output tokens = 466

# %% [markdown]
# ## Preparing target data for the Decoder

# %%
decoder_target_data = list()
for token_seq in tokenized_output_lines:
    decoder_target_data.append( token_seq[ 1 : ] ) 
    
padded_output_lines = preprocessing.sequence.pad_sequences( decoder_target_data , maxlen=max_output_length, padding='post' )
onehot_output_lines = utils.to_categorical( padded_output_lines , num_output_tokens )
decoder_target_data = np.array( onehot_output_lines )
print( 'Decoder target data shape -> {}'.format( decoder_target_data.shape ))
# Out:
# Decoder target data shape -> (600, 8, 466)

# %%
encoder_inputs = tf.keras.layers.Input(shape=( None , ))
encoder_embedding = tf.keras.layers.Embedding( num_input_tokens, 256 , mask_zero=True ) (encoder_inputs)
encoder_outputs , state_h , state_c = tf.keras.layers.LSTM( 256 , return_state=True , recurrent_dropout=0.2 , dropout=0.2 )( encoder_embedding )
encoder_states = [ state_h , state_c ]

decoder_inputs = tf.keras.layers.Input(shape=( None ,  ))
decoder_embedding = tf.keras.layers.Embedding( num_output_tokens, 256 , mask_zero=True) (decoder_inputs)
decoder_lstm = tf.keras.layers.LSTM( 256 , return_state=True , return_sequences=True , recurrent_dropout=0.2 , dropout=0.2)
decoder_outputs , _ , _ = decoder_lstm ( decoder_embedding , initial_state=encoder_states )
decoder_dense = tf.keras.layers.Dense( num_output_tokens , activation=tf.keras.activations.softmax ) 
output = decoder_dense ( decoder_outputs )

model = tf.keras.models.Model([encoder_inputs, decoder_inputs], output )
model.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy')

model.summary()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None)]       0           []
#
#  input_2 (InputLayer)           [(None, None)]       0           []
#
#  embedding (Embedding)          (None, None, 256)    44032       ['input_1[0][0]']
#
#  embedding_1 (Embedding)        (None, None, 256)    119296      ['input_2[0][0]']
#
#  lstm (LSTM)                    [(None, 256),        525312      ['embedding[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_1 (LSTM)                  [(None, None, 256),  525312      ['embedding_1[0][0]',
#                                  (None, 256),                     'lstm[0][1]',
#                                  (None, 256)]                     'lstm[0][2]']
#
#  dense (Dense)                  (None, None, 466)    119762      ['lstm_1[0][0]']
#
# ==================================================================================================
# Total params: 1,333,714
# Trainable params: 1,333,714
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training

# %%
## model require more number of epoches to train as it is sequential problem so i have used 500 epochs here
model.fit([encoder_input_data , decoder_input_data], decoder_target_data, batch_size=124, epochs=500) 
model.save('model.h5')
# Out:
# Epoch 1/500
# 5/5 [==============================] - 9s 74ms/step - loss: 3.0757
# Epoch 2/500
# 5/5 [==============================] - 0s 74ms/step - loss: 3.0077
# Epoch 3/500
# 5/5 [==============================] - 0s 82ms/step - loss: 2.7468
# Epoch 4/500
# 5/5 [==============================] - 0s 84ms/step - loss: 2.0912
# Epoch 5/500
# 5/5 [==============================] - 0s 78ms/step - loss: 1.8667
# Epoch 6/500
# 5/5 [==============================] - 0s 80ms/step - loss: 1.8475
# Epoch 7/500
# 5/5 [==============================] - 0s 76ms/step - loss: 1.7369
# Epoch 8/500
# 5/5 [==============================] - 0s 83ms/step - loss: 1.7015
# Epoch 9/500
# 5/5 [==============================] - 0s 78ms/step - loss: 1.6638
# Epoch 10/500
# 5/5 [==============================] - 0s 77ms/step - loss: 1.6270
# Epoch 11/500
# 5/5 [==============================] - 0s 81ms/step - loss: 1.6031
# Epoch 12/500
# 5/5 [==============================] - 0s 75ms/step - loss: 1.5745
# Epoch 13/500
# 5/5 [==============================] - 0s 81ms/step - loss: 1.5507
# Epoch 14/500
# 5/5 [==============================] - 0s 83ms/step - loss: 1.5313
# Epoch 15/500
# 5/5 [==============================] - 0s 83ms/step - loss: 1.5122
# Epoch 16/500
# 5/5 [==============================] - 0s 80ms/step - loss: 1.4918
# Epoch 17/500
# 5/5 [==============================] - 0s 82ms/step - loss: 1.4715
# Epoch 18/500
# 5/5 [==============================] - 0s 84ms/step - loss: 1.4506
# Epoch 19/500
# 5/5 [==============================] - 0s 74ms/step - loss: 1.4285
# Epoch 20/500
# 5/5 [==============================] - 0s 78ms/step - loss: 1.4062
# Epoch 21/500
# 5/5 [==============================] - 0s 81ms/step - loss: 1.3806
# Epoch 22/500
# 5/5 [==============================] - 0s 82ms/step - loss: 1.3558
# Epoch 23/500
# 5/5 [==============================] - 0s 82ms/step - loss: 1.3309
# Epoch 24/500
# 5/5 [==============================] - 0s 82ms/step - loss: 1.3044
# Epoch 25/500
# 5/5 [==============================] - 0s 80ms/step - loss: 1.2810
# Epoch 26/500
# 5/5 [==============================] - 0s 83ms/step - loss: 1.2530
# Epoch 27/500
# 5/5 [==============================] - 0s 80ms/step - loss: 1.2249
# Epoch 28/500
# 5/5 [==============================] - 0s 78ms/step - loss: 1.1988
# Epoch 29/500
# 5/5 [==============================] - 0s 86ms/step - loss: 1.1713
# Epoch 30/500
# 5/5 [==============================] - 0s 72ms/step - loss: 1.1434
500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.2086
# Epoch 146/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.2109
# Epoch 147/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.2089
# Epoch 148/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.2087
# Epoch 149/500
# 5/5 [==============================] - 0s 82ms/step - loss: 0.2087
# Epoch 150/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.2094
# Epoch 151/500
# 5/5 [==============================] - 0s 79ms/step - loss: 0.2089
# Epoch 152/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.2074
# Epoch 153/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.2083
# Epoch 154/500
# 5/5 [==============================] - 0s 80ms/step - loss: 0.2072
# Epoch 155/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.2080
# Epoch 156/500
# 5/5 [==============================] - 0s 83ms/step - loss: 0.2053
# Epoch 157/500
# 5/5 [==============================] - 0s 74ms/step - loss: 0.2063
# Epoch 158/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.2055
# Epoch 159/500
# 5/5 [==============================] - 0s 73ms/step - loss: 0.2050
# Epoch 160/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.2060
# Epoch 161/500
# 5/5 [==============================] - 0s 72ms/step - loss: 0.2078
# Epoch 162/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.2055
# Epoch 163/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.2053
# Epoch 164/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.2056
# Epoch 165/500
# 5/5 [==============================] - 0s 73ms/step - loss: 0.2052
# Epoch 166/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.2055
# Epoch 167/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.2050
# Epoch 168/500
# 5/5 [==============================] - 0s 79ms/step - loss: 0.2040
# Epoch 169/500
# 5/5 [==============================] - 0s 73ms/step - loss: 0.2053
# Epoch 170/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.2031
# Epoch 171/500
# 5/5 [==============================] - 0s 82ms/step - loss: 0.2044
# Epoch 172/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.2057
# Epoch 173/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.2043
# Epoch 174/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.2035
# Epoch 175/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.2047
# Epoch 176/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.2021
# Epoch 177/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.2030
# Epoch 178/500
# 5/5 [==============================] - 0s 72ms/step - loss: 0.2035
# Epoch 179/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.2039
# Epoch 180/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.2024
# Epoch 181/500
# 5/5 [==============================] - 0s 79ms/step - loss: 0.2047
# Epoch 182/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.2017
# Epoch 183/500
# 5/5 [==============================] - 0s 79ms/step - loss: 0.2022
# Epoch 184/500
# 5/5 [==============================] - 0s 79ms/step - loss: 0.2036
# Epoch 185/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.2034
# Epoch 186/500
# 5/5 [==============================] - 0s 82ms/step - loss: 0.2037
# Epoch 187/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.2030
# Epoch 188/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.2012
# Epoch 189/500
# 5/5 [==============================] - 0s 79ms/step - loss: 0.2013
# Epoch 190/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.2009
# Epoch 191/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.2020
# Epoch 192/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.2024
# Epoch 193/500
# 5/5 [==============================] - 0s 74ms/step - loss: 0.2029
# Epoch 194/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.2032
# Epoch 195/500
# 5/5 [==============================] - 0s 73ms/step - loss: 0.2029
# Epoch 196/500
# 5/5 [==============================] - 0s 79ms/step - loss: 0.2021
# Epoch 197/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.2022
# Epoch 198/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.2018
# Epoch 199/500
# 5/5 [==============================] - 0s 80ms/step - loss: 0.2028
# Epoch 200/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.2031
# Epoch 201/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.2027
# Epoch 202/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.2006
# Epoch 203/500
# 5/5 [==============================] - 0s 79ms/step - loss: 0.2020
# Epoch 204/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.2013
# Epoch 205/500
# 5/5 [==============================] - 0s 81ms/step - loss: 0.2007
# Epoch 206/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.2006
# Epoch 207/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.1998
# Epoch 208/500
# 5/5 [==============================] - 0s 74ms/step - loss: 0.2001
# Epoch 209/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.2011
# Epoch 210/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.2012
# Epoch 211/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.2008
# Epoch 212/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.1987
# Epoch 213/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.2008
# Epoch 214/500
# 5/5 [==============================] - 0s 74ms/step - loss: 0.2002
# Epoch 215/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.2006
# Epoch 216/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.2002
# Epoch 217/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.1996
# Epoch 218/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.1999
# Epoch 219/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.1998
# Epoch 220/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.2005
# Epoch 221/500
# 5/5 [==============================] - 0s 82ms/step - loss: 0.2000
# Epoch 222/500
# 5/5 [==============================] - 0s 79ms/step - loss: 0.2003
# Epoch 223/500
# 5/5 [==============================] - 0s 83ms/step - loss: 0.1999
# Epoch 224/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.2002
# Epoch 225/500
# 5/5 [==============================] - 0s 83ms/step - loss: 0.1981
# Epoch 226/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.1991
# Epoch 227/500
# 5/5 [==============================] - 0s 79ms/step - loss: 0.2002
# Epoch 228/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.1992
# Epoch 229/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.1994
# Epoch 230/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.1995
# Epoch 231/500
# 5/5 [==============================] - 0s 82ms/step - loss: 0.1992
# Epoch 232/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.2009
# Epoch 233/500
# 5/5 [==============================] - 0s 80ms/step - loss: 0.2000
# Epoch 234/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.1998
# Epoch 235/500
# 5/5 [==============================] - 0s 74ms/step - loss: 0.1987
# Epoch 236/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.1990
# Epoch 237/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.1990
# Epoch 238/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.1988
# Epoch 239/500
# 5/5 [==============================] - 0s 80ms/step - loss: 0.1991
# Epoch 240/500
# 5/5 [==============================] - 0s 74ms/step - loss: 0.1976
# Epoch 241/500
# 5/5 [==============================] - 0s 80ms/step - loss: 0.2001
# Epoch 242/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.1994
# Epoch 243/500
# 5/5 [==============================] - 0s 81ms/step - loss: 0.1997
# Epoch 244/500
# 5/5 [==============================] - 0s 79ms/step - loss: 0.1986
# Epoch 245/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.1980
# Epoch 246/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.1999
# Epoch 247/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.1980
# Epoch 248/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.1982
# Epoch 249/500
# 5/5 [==============================] - 0s 74ms/step - loss: 0.1996
# Epoch 250/500
# 5/5 [==============================] - 0s 74ms/step - loss: 0.1991
# Epoch 251/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.1982
# Epoch 252/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.1979
# Epoch 253/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.1990
# Epoch 254/500
# 5/5 [==============================] - 0s 79ms/step - loss: 0.1993
# Epoch 255/500
# 5/5 [==============================] - 0s 74ms/step - loss: 0.1983
# Epoch 256/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.1998
# Epoch 257/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.1982
# Epoch 258/500
# 5/5 [==============================] - 0s 74ms/step - loss: 0.1988
# Epoch 259/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.1981
# Epoch 260/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.1983
# Epoch 261/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.1982
# Epoch 262/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.1975
# Epoch 263/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.1988
# Epoch 264/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.1982
# Epoch 265/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.1985
# Epoch 266/500
# 5/5 [==============================] - 0s 73ms/step - loss: 0.1980
# Epoch 267/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.1978
# Epoch 268/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.1994
# Epoch 269/500
# 5/5 [==============================] - 0s 82ms/step - loss: 0.1986
# Epoch 270/500
# 5/5 [==============================] - 0s 79ms/step - loss: 0.1990
# Epoch 271/500
# 5/5 [==============================] - 0s 74ms/step - loss: 0.1982
# Epoch 272/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.1975
# Epoch 273/500
# 5/5 [==============================] - 0s 80ms/step - loss: 0.1976
# Epoch 274/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.1990
# Epoch 275/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.1980
# Epoch 276/500
# 5/5 [==============================] - 0s 73ms/step - loss: 0.1992
# Epoch 277/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.1971
# Epoch 278/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.
500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.1953
# Epoch 408/500
# 5/5 [==============================] - 0s 82ms/step - loss: 0.1952
# Epoch 409/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.1962
# Epoch 410/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.1955
# Epoch 411/500
# 5/5 [==============================] - 0s 80ms/step - loss: 0.1945
# Epoch 412/500
# 5/5 [==============================] - 0s 74ms/step - loss: 0.1943
# Epoch 413/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.1956
# Epoch 414/500
# 5/5 [==============================] - 0s 79ms/step - loss: 0.1954
# Epoch 415/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.1959
# Epoch 416/500
# 5/5 [==============================] - 0s 81ms/step - loss: 0.1955
# Epoch 417/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.1950
# Epoch 418/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.1955
# Epoch 419/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.1943
# Epoch 420/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.1964
# Epoch 421/500
# 5/5 [==============================] - 0s 82ms/step - loss: 0.1951
# Epoch 422/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.1966
# Epoch 423/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.1960
# Epoch 424/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.1959
# Epoch 425/500
# 5/5 [==============================] - 0s 82ms/step - loss: 0.1951
# Epoch 426/500
# 5/5 [==============================] - 0s 80ms/step - loss: 0.1949
# Epoch 427/500
# 5/5 [==============================] - 0s 79ms/step - loss: 0.1952
# Epoch 428/500
# 5/5 [==============================] - 0s 74ms/step - loss: 0.1951
# Epoch 429/500
# 5/5 [==============================] - 0s 80ms/step - loss: 0.1957
# Epoch 430/500
# 5/5 [==============================] - 0s 81ms/step - loss: 0.1948
# Epoch 431/500
# 5/5 [==============================] - 0s 81ms/step - loss: 0.1945
# Epoch 432/500
# 5/5 [==============================] - 0s 79ms/step - loss: 0.1954
# Epoch 433/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.1948
# Epoch 434/500
# 5/5 [==============================] - 0s 82ms/step - loss: 0.1960
# Epoch 435/500
# 5/5 [==============================] - 0s 79ms/step - loss: 0.1950
# Epoch 436/500
# 5/5 [==============================] - 0s 81ms/step - loss: 0.1946
# Epoch 437/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.1943
# Epoch 438/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.1955
# Epoch 439/500
# 5/5 [==============================] - 0s 81ms/step - loss: 0.1951
# Epoch 440/500
# 5/5 [==============================] - 0s 81ms/step - loss: 0.1964
# Epoch 441/500
# 5/5 [==============================] - 0s 80ms/step - loss: 0.1964
# Epoch 442/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.1944
# Epoch 443/500
# 5/5 [==============================] - 0s 80ms/step - loss: 0.1951
# Epoch 444/500
# 5/5 [==============================] - 0s 81ms/step - loss: 0.1945
# Epoch 445/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.1950
# Epoch 446/500
# 5/5 [==============================] - 0s 80ms/step - loss: 0.1957
# Epoch 447/500
# 5/5 [==============================] - 0s 82ms/step - loss: 0.1945
# Epoch 448/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.1948
# Epoch 449/500
# 5/5 [==============================] - 0s 79ms/step - loss: 0.1950
# Epoch 450/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.1958
# Epoch 451/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.1964
# Epoch 452/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.1954
# Epoch 453/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.1953
# Epoch 454/500
# 5/5 [==============================] - 0s 80ms/step - loss: 0.1966
# Epoch 455/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.1952
# Epoch 456/500
# 5/5 [==============================] - 0s 80ms/step - loss: 0.1943
# Epoch 457/500
# 5/5 [==============================] - 0s 82ms/step - loss: 0.1952
# Epoch 458/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.1955
# Epoch 459/500
# 5/5 [==============================] - 0s 83ms/step - loss: 0.1955
# Epoch 460/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.1952
# Epoch 461/500
# 5/5 [==============================] - 0s 79ms/step - loss: 0.1955
# Epoch 462/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.1952
# Epoch 463/500
# 5/5 [==============================] - 0s 79ms/step - loss: 0.1942
# Epoch 464/500
# 5/5 [==============================] - 0s 80ms/step - loss: 0.1954
# Epoch 465/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.1951
# Epoch 466/500
# 5/5 [==============================] - 0s 79ms/step - loss: 0.1946
# Epoch 467/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.1951
# Epoch 468/500
# 5/5 [==============================] - 0s 86ms/step - loss: 0.1951
# Epoch 469/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.1949
# Epoch 470/500
# 5/5 [==============================] - 0s 81ms/step - loss: 0.1952
# Epoch 471/500
# 5/5 [==============================] - 0s 79ms/step - loss: 0.1952
# Epoch 472/500
# 5/5 [==============================] - 0s 81ms/step - loss: 0.1951
# Epoch 473/500
# 5/5 [==============================] - 0s 79ms/step - loss: 0.1955
# Epoch 474/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.1946
# Epoch 475/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.1953
# Epoch 476/500
# 5/5 [==============================] - 0s 81ms/step - loss: 0.1954
# Epoch 477/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.1946
# Epoch 478/500
# 5/5 [==============================] - 0s 74ms/step - loss: 0.1954
# Epoch 479/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.1955
# Epoch 480/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.1954
# Epoch 481/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.1944
# Epoch 482/500
# 5/5 [==============================] - 0s 83ms/step - loss: 0.1945
# Epoch 483/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.1956
# Epoch 484/500
# 5/5 [==============================] - 0s 81ms/step - loss: 0.1953
# Epoch 485/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.1946
# Epoch 486/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.1940
# Epoch 487/500
# 5/5 [==============================] - 0s 82ms/step - loss: 0.1948
# Epoch 488/500
# 5/5 [==============================] - 0s 80ms/step - loss: 0.1950
# Epoch 489/500
# 5/5 [==============================] - 0s 81ms/step - loss: 0.1951
# Epoch 490/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.1945
# Epoch 491/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.1940
# Epoch 492/500
# 5/5 [==============================] - 0s 81ms/step - loss: 0.1945
# Epoch 493/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.1959
# Epoch 494/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.1954
# Epoch 495/500
# 5/5 [==============================] - 0s 74ms/step - loss: 0.1950
# Epoch 496/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.1956
# Epoch 497/500
# 5/5 [==============================] - 0s 80ms/step - loss: 0.1959
# Epoch 498/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.1950
# Epoch 499/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.1950
# Epoch 500/500
# 5/5 [==============================] - 0s 79ms/step - loss: 0.1957

# %% [markdown]
# ## Inference models

# %%
def make_inference_models():
    
    encoder_model = tf.keras.models.Model(encoder_inputs, encoder_states)
    
    decoder_state_input_h = tf.keras.layers.Input(shape=(256,))
    decoder_state_input_c = tf.keras.layers.Input(shape=(256,))
    
    decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
    
    decoder_outputs, state_h, state_c = decoder_lstm(
        decoder_embedding , initial_state=decoder_states_inputs)
    decoder_states = [state_h, state_c]
    decoder_outputs = decoder_dense(decoder_outputs)
    decoder_model = tf.keras.models.Model(
        [decoder_inputs] + decoder_states_inputs,
        [decoder_outputs] + decoder_states)
    
    return encoder_model , decoder_model

# %%
def str_to_tokens( sentence : str ):
    words = sentence.lower().split()
    tokens_list = list()
    for word in words:
        tokens_list.append( input_word_dict[ word ] ) 
    return preprocessing.sequence.pad_sequences( [tokens_list] , maxlen=max_input_length , padding='post')

# %%
enc_model , dec_model = make_inference_models()

for epoch in range( encoder_input_data.shape[0] ):
    states_values = enc_model.predict( str_to_tokens( input( 'English text: ' ) ) )
    empty_target_seq = np.zeros( ( 1 , 1 ) )
    empty_target_seq[0, 0] = output_word_dict['start']
    stop_condition = False
    decoded_translation = ''
    while not stop_condition :
        dec_outputs , h , c = dec_model.predict([ empty_target_seq ] + states_values )
        sampled_word_index = np.argmax( dec_outputs[0, -1, :] )
        sampled_word = None
        for word , index in output_word_dict.items() :
            if sampled_word_index == index :
                decoded_translation += ' {}'.format( word )
                sampled_word = word
        
        if sampled_word == 'end' or len(decoded_translation.split()) > max_output_length:
            stop_condition = True
            
        empty_target_seq = np.zeros( ( 1 , 1 ) )  
        empty_target_seq[ 0 , 0 ] = sampled_word_index
        states_values = [ h , c ] 

    print( "French text:" +decoded_translation.replace(' end', '') )
    print()
# Out:
# English text: hi
# French text: salut
#
# English text: Get out
# French text: sortez
#
# English text: Burn it
# French text: brûle la
#
# English text: Call me
# French text: appelle moi
